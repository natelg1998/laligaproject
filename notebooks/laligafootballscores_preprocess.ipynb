# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
import os
import glob
from pathlib import Path

# %%
file_path = Path(os.path.realpath('../data/scores.csv'))
print(file_path)
# Out:
# C:\Users\ntlg4\PycharmProjects\laliga\data\scores.csv

# %%
scores_df = pd.read_csv(file_path)

# %%
scores_df
# Out:
#         Unnamed: 0        Date   Time       Comp           Round  Day Venue  \
# 0                0  2022-08-10  22:00  Super Cup  UEFA Super Cup  Wed  Home
# 1                1  2022-08-14  22:00    La Liga     Matchweek 1  Sun  Away
# 2                2  2022-08-20  22:00    La Liga     Matchweek 2  Sat  Away
# 3                3  2022-08-28  22:00    La Liga     Matchweek 3  Sun  Away
# 4                4  2022-09-03  16:15    La Liga     Matchweek 4  Sat  Home
# ...            ...         ...    ...        ...             ...  ...   ...
# 353155          33  2006-04-23    NaN    La Liga    Matchweek 34  Sun  Home
# 353156          34  2006-04-29    NaN    La Liga    Matchweek 35  Sat  Away
# 353157          35  2006-05-03    NaN    La Liga    Matchweek 36  Wed  Home
# 353158          36  2006-05-07    NaN    La Liga    Matchweek 37  Sun  Away
# 353159          37  2006-05-13    NaN    La Liga    Matchweek 38  Sat  Home
#
# ...

# %%
scores_liga = scores_df[(scores_df["Comp"] == "La Liga") | (scores_df["Comp"] == "Segunda Division")]

# %%
scores_liga
# Out:
#         Unnamed: 0        Date   Time     Comp         Round  Day Venue  \
# 1                1  2022-08-14  22:00  La Liga   Matchweek 1  Sun  Away
# 2                2  2022-08-20  22:00  La Liga   Matchweek 2  Sat  Away
# 3                3  2022-08-28  22:00  La Liga   Matchweek 3  Sun  Away
# 4                4  2022-09-03  16:15  La Liga   Matchweek 4  Sat  Home
# 6                6  2022-09-11  14:00  La Liga   Matchweek 5  Sun  Home
# ...            ...         ...    ...      ...           ...  ...   ...
# 353155          33  2006-04-23    NaN  La Liga  Matchweek 34  Sun  Home
# 353156          34  2006-04-29    NaN  La Liga  Matchweek 35  Sat  Away
# 353157          35  2006-05-03    NaN  La Liga  Matchweek 36  Wed  Home
# 353158          36  2006-05-07    NaN  La Liga  Matchweek 37  Sun  Away
# 353159          37  2006-05-13    NaN  La Liga  Matchweek 38  Sat  Home
#
#        Result   GF   GA  ...   xG  xGA  Poss  Attendance        Captain  \
# ...
