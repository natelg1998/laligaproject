# %% [markdown]
# # FBRef Data Preprocess

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')


pd.set_option('display.max_rows', 12000)
pd.set_option('display.max_columns', 12000)
pd.set_option('display.width', 12000)
pd.set_option('display.max_colwidth', 12000)

# %%
FILE_PATH = os.path.realpath("../data/fbref_data")

# %%
SCORES_DATA = os.path.join(FILE_PATH, "scores.csv")
SCORES_DATA
# Out:
# 'C:\\Users\\ntlg4\\PycharmProjects\\laliga\\data\\fbref_data\\scores.csv'

# %%
scores_df = pd.read_csv(SCORES_DATA)
scores_df
# Out:
#        Unnamed: 0        Date   Time          Comp         Round  Day Venue Result GF GA          Opponent   xG  xGA  Poss  Attendance        Captain Formation              Referee  Match Report Notes         Team
# 0               0  2011-08-28    NaN       La Liga   Matchweek 2  Sun  Away      W  6  0          Zaragoza  NaN  NaN   NaN         NaN            NaN       NaN      Muñiz Fernández  Match Report   NaN  Real Madrid
# 1               1  2011-09-10    NaN       La Liga   Matchweek 3  Sat  Home      W  4  2            Getafe  NaN  NaN   NaN         NaN            NaN       NaN           Clos Gómez  Match Report   NaN  Real Madrid
# 2               2  2011-09-14    NaN  Champions Lg   Group stage  Wed  Away      W  1  0  hr Dinamo Zagreb  NaN  NaN   NaN         NaN            NaN       NaN    Svein Oddvar Moen  Match Report   NaN  Real Madrid
# 3               3  2011-09-18    NaN       La Liga   Matchweek 4  Sun  Away      L  0  1           Levante  NaN  NaN   NaN         NaN            NaN       NaN     Turienzo Álvarez  Match Report   NaN  Real Madrid
# 4               4  2011-09-21    NaN       La Liga   Matchweek 5  Wed  Away      D  0  0       Racing Sant  NaN  NaN   NaN         NaN            NaN       NaN   Fernández Borbalán  Match Report   NaN  Real Madrid
# ...           ...         ...    ...           ...           ...  ...   ...    ... .. ..               ...  ...  ...   ...         ...            ...       ...                  ...           ...   ...          ...
# 16848       16848  2022-05-01  14:00       La Liga  Matchweek 34  Sun  Home      D  1  1           Osasuna  0.4  1.1  57.0     16305.0  Gonzalo Verdú     3-4-3     Carlos del Cerro  Match Report   NaN        Elche
# 16849       16849  2022-05-07  18:30       La Liga  Matchweek 35  Sat  Away      L  0  3             Cádiz  0.1  2.3  44.0     17615.0    Édgar Badía     3-4-3  Alejandro Hernández  Match Report   NaN        Elche
# 16850       16850  2022-05-11  21:30       La Liga  Matchweek 36  Wed  Home      L  0  2   Atlético Madrid  0.2  2.1  55.0     21266.0          Fidel   4-2-3-1       Pablo González  Match Report   NaN        Elche
# 16851       16851  2022-05-15  19:30       La Liga  Matchweek 37  Sun  Away      L  0  1        Celta Vigo  0.7  2.2  52.0     10773.0          Josan     3-5-2         Mario Melero  Match Report   NaN        Elche
# 16852       16852  2022-05-22  17:30       La Liga  Matchweek 38  Sun  Home      W  3  1            Getafe  2.5  1.3  59.0     17336.0     Pere Milla     3-4-3     Guillermo Cuadra  Match Report   NaN        Elche
#
# [16853 rows x 21 columns]

# %%
scores_df = scores_df[scores_df['Comp'] == 'La Liga']
scores_df
# Out:
#        Unnamed: 0        Date   Time     Comp         Round  Day Venue Result GF GA         Opponent   xG  xGA  Poss  Attendance        Captain Formation              Referee  Match Report Notes         Team
# 0               0  2011-08-28    NaN  La Liga   Matchweek 2  Sun  Away      W  6  0         Zaragoza  NaN  NaN   NaN         NaN            NaN       NaN      Muñiz Fernández  Match Report   NaN  Real Madrid
# 1               1  2011-09-10    NaN  La Liga   Matchweek 3  Sat  Home      W  4  2           Getafe  NaN  NaN   NaN         NaN            NaN       NaN           Clos Gómez  Match Report   NaN  Real Madrid
# 3               3  2011-09-18    NaN  La Liga   Matchweek 4  Sun  Away      L  0  1          Levante  NaN  NaN   NaN         NaN            NaN       NaN     Turienzo Álvarez  Match Report   NaN  Real Madrid
# 4               4  2011-09-21    NaN  La Liga   Matchweek 5  Wed  Away      D  0  0      Racing Sant  NaN  NaN   NaN         NaN            NaN       NaN   Fernández Borbalán  Match Report   NaN  Real Madrid
# 5               5  2011-09-24    NaN  La Liga   Matchweek 6  Sat  Home      W  6  2   Rayo Vallecano  NaN  NaN   NaN         NaN            NaN       NaN       Paradas Romero  Match Report   NaN  Real Madrid
# ...           ...         ...    ...      ...           ...  ...   ...    ... .. ..              ...  ...  ...   ...         ...            ...       ...                  ...           ...   ...          ...
# 16848       16848  2022-05-01  14:00  La Liga  Matchweek 34  Sun  Home      D  1  1          Osasuna  0.4  1.1  57.0     16305.0  Gonzalo Verdú     3-4-3     Carlos del Cerro  Match Report   NaN        Elche
# 16849       16849  2022-05-07  18:30  La Liga  Matchweek 35  Sat  Away      L  0  3            Cádiz  0.1  2.3  44.0     17615.0    Édgar Badía     3-4-3  Alejandro Hernández  Match Report   NaN        Elche
# 16850       16850  2022-05-11  21:30  La Liga  Matchweek 36  Wed  Home      L  0  2  Atlético Madrid  0.2  2.1  55.0     21266.0          Fidel   4-2-3-1       Pablo González  Match Report   NaN        Elche
# 16851       16851  2022-05-15  19:30  La Liga  Matchweek 37  Sun  Away      L  0  1       Celta Vigo  0.7  2.2  52.0     10773.0          Josan     3-5-2         Mario Melero  Match Report   NaN        Elche
# 16852       16852  2022-05-22  17:30  La Liga  Matchweek 38  Sun  Home      W  3  1           Getafe  2.5  1.3  59.0     17336.0     Pere Milla     3-4-3     Guillermo Cuadra  Match Report   NaN        Elche
#
# [12388 rows x 21 columns]
