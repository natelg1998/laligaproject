# %% [markdown]
# # FBRef Data Preprocess

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# %%
FILE_PATH = os.path.realpath("../data/fbref_data")

# %%
SCORES_DATA = os.path.join(FILE_PATH, "scores.csv")

# %%
scores_df = pd.read_csv(SCORES_DATA)

# %%
scores_df = scores_df[scores_df['Comp'] == 'La Liga']
scores_df = scores_df.sort_values(["Date", "Time"])
scores_df.drop(["Unnamed: 0", "Match Report", "Notes"], axis = 1, inplace = True)
scores_df['Team'] = scores_df['Team'].replace({'Alaves': 'Alavés', 'Almeria': 'Almería', 'Atletico Madrid' : 'Atlético Madrid', 'Real Betis' : 'Betis', 
                                               'Cadiz' : 'Cádiz', 'Cordoba': 'Córdoba', 'Gimnastic' : 'Gimnàstic', 'Deportivo La Coruna' : 'La Coruña',
                                              'Hercules' : 'Hércules', 'Leganes' : 'Leganés', 'Malaga' : 'Málaga', 'Racing Santander' : 'Racing Sant', 'Sporting Gijon' : 'Sporting Gijón'})

start_date = '2000-08-29'
end_date = '2022-05-30'
mask = (scores_df['Date'] > start_date) & (scores_df['Date'] <= end_date)
scores_df = scores_df.loc[mask]
scores_df.head()
# Out:
#              Date Time     Comp        Round  Day Venue Result GF GA  \
# 19184  2000-09-09  NaN  La Liga  Matchweek 1  Sat  Away      L  1  2
# 19315  2000-09-09  NaN  La Liga  Matchweek 1  Sat  Home      W  2  0
# 19415  2000-09-09  NaN  La Liga  Matchweek 1  Sat  Away      L  1  2
# 19504  2000-09-09  NaN  La Liga  Matchweek 1  Sat  Away      L  0  2
# 19542  2000-09-09  NaN  La Liga  Matchweek 1  Sat  Home      W  2  1
#
#             Opponent  xG  xGA  Poss  Attendance Captain Formation  \
# 19184    Real Madrid NaN  NaN   NaN         NaN     NaN       NaN
# 19315  Athletic Club NaN  NaN   NaN         NaN     NaN       NaN
# 19415      Barcelona NaN  NaN   NaN         NaN     NaN       NaN
# 19504      La Coruña NaN  NaN   NaN         NaN     NaN       NaN
# 19542         Málaga NaN  NaN   NaN         NaN     NaN       NaN
#
#                   Referee           Team
# 19184       Daudén Ibáñez       Valencia
# 19315  Andradas Asurmendi      La Coruña
# 19415     Mejuto González         Málaga
# 19504  Andradas Asurmendi  Athletic Club
# 19542     Mejuto González      Barcelona

# %%
scores_df['Date'] = pd.to_datetime(scores_df['Date'], format = "%Y-%m-%d")
scores_df['Time'] = pd.to_datetime(scores_df['Time']).dt.time

# %%
scores_df_merge = scores_df.merge(scores_df, left_on = ["Date", "Time", "Comp", "Day", "Round", "Team", "Referee", "Attendance"], right_on = ["Date", "Time", "Comp", "Day", "Round", "Opponent", "Referee", "Attendance"],
                                 suffixes = ("_team", "_opponent"), how = "left")
scores_df_merge
# Out:
#             Date      Time     Comp         Round  Day Venue_team Result_team  \
# 0     2000-09-09       NaN  La Liga   Matchweek 1  Sat       Away           L
# 1     2000-09-09       NaN  La Liga   Matchweek 1  Sat       Home           W
# 2     2000-09-09       NaN  La Liga   Matchweek 1  Sat       Away           L
# 3     2000-09-09       NaN  La Liga   Matchweek 1  Sat       Away           L
# 4     2000-09-09       NaN  La Liga   Matchweek 1  Sat       Home           W
# ...          ...       ...      ...           ...  ...        ...         ...
# 16715 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun       Away           L
# 16716 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun       Home           W
# 16717 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun       Home           L
# 16718 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun       Away           W
# 16719 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun       Home           L
#
#       GF_team GA_team    Opponent_team  ...  Result_opponent  GF_opponent  \
# 0           1       2      Real Madrid  ...                W            2
# 1           2       0    Athletic Club  ...                L            0
# 2           1       2        Barcelona  ...                W            2
# 3           0       2        La Coruña  ...                W            2
# 4           2       1           Málaga  ...                L            1
# ...       ...     ...              ...  ...              ...          ...
# 16715       0       1          Sevilla  ...                W            1
# 16716       1       0    Athletic Club  ...                L            0
# 16717       1       2  Atlético Madrid  ...                W            2
# 16718       2       0        Barcelona  ...                L            0
# 16719       0       2       Villarreal  ...                W            2
#
#        GA_opponent  Opponent_opponent xG_opponent xGA_opponent Poss_opponent  \
# 0                1           Valencia         NaN          NaN           NaN
# 1                2          La Coruña         NaN          NaN           NaN
# 2                1             Málaga         NaN          NaN           NaN
# 3                0      Athletic Club         NaN          NaN           NaN
# 4                2          Barcelona         NaN          NaN           NaN
# ...            ...                ...         ...          ...           ...
# 16715            0      Athletic Club         1.4          0.7          65.0
# 16716            1            Sevilla         0.7          1.4          35.0
# 16717            1      Real Sociedad         0.8          2.3          39.0
# 16718            2         Villarreal         0.7          0.7          70.0
# 16719            0          Barcelona         0.7          0.7          30.0
#
#       Captain_opponent Formation_opponent    Team_opponent
# 0                  NaN                NaN      Real Madrid
# 1                  NaN                NaN    Athletic Club
# 2                  NaN                NaN        Barcelona
# 3                  NaN                NaN        La Coruña
# 4                  NaN                NaN           Málaga
# ...                ...                ...              ...
# 16715      Jesús Navas              4-3-3          Sevilla
# 16716     Iker Muniain              4-4-2    Athletic Club
# 16717             Koke              3-5-2  Atlético Madrid
# 16718  Sergio Busquets              4-3-3        Barcelona
# 16719     Mario Gaspar              4-4-2       Villarreal
#
# [16720 rows x 29 columns]

# %%
scores_df_merge['Home'] = np.where(scores_df_merge['Venue_team'] == 'Home', scores_df_merge['Team_team'], scores_df_merge['Opponent_team'])
scores_df_merge['Away'] = np.where(scores_df_merge['Team_team'] == scores_df_merge['Home'], scores_df_merge['Opponent_team'], scores_df_merge['Team_team'])
scores_df_merge['HomeGoal'] = np.where(scores_df_merge['Team_team'] == scores_df_merge['Home'], scores_df_merge['GF_team'], scores_df_merge['GA_team'])
scores_df_merge['HomeGoal'] = scores_df_merge['HomeGoal'].astype(float).astype(int)
scores_df_merge['xG_Home'] = np.where(scores_df_merge['Team_team'] == scores_df_merge['Home'], scores_df_merge['xG_team'], scores_df_merge['xGA_team'])
scores_df_merge['AwayGoal'] = np.where(scores_df_merge['Team_team'] == scores_df_merge['Away'], scores_df_merge['GF_team'], scores_df_merge['GA_team'])
scores_df_merge['AwayGoal'] = scores_df_merge['AwayGoal'].astype(float).astype(int)
scores_df_merge['xG_Away'] = np.where(scores_df_merge['Team_team'] == scores_df_merge['Away'], scores_df_merge['xG_team'], scores_df_merge['xGA_team'])
scores_df_merge['HomeFormation'] = np.where(scores_df_merge['Team_team'] == scores_df_merge['Home'], scores_df_merge['Formation_team'], scores_df_merge['Formation_opponent'])
scores_df_merge['AwayFormation'] = np.where(scores_df_merge['Team_team'] == scores_df_merge['Away'], scores_df_merge['Formation_team'], scores_df_merge['Formation_opponent'])
scores_df_merge['HomePossession'] = np.where(scores_df_merge['Team_team'] == scores_df_merge['Home'], scores_df_merge['Poss_team'], scores_df_merge['Poss_opponent'])
scores_df_merge['AwayPossession'] = np.where(scores_df_merge['Team_team'] == scores_df_merge['Away'], scores_df_merge['Poss_team'], scores_df_merge['Poss_opponent'])
scores_df_merge['HomeCaptain'] = np.where(scores_df_merge['Team_team'] == scores_df_merge['Home'], scores_df_merge['Captain_team'], scores_df_merge['Captain_opponent'])
scores_df_merge['AwayCaptain'] = np.where(scores_df_merge['Team_team'] == scores_df_merge['Away'], scores_df_merge['Captain_team'], scores_df_merge['Captain_opponent'])

scores_df_merge
# Out:
#             Date      Time     Comp         Round  Day Venue_team Result_team  \
# 0     2000-09-09       NaN  La Liga   Matchweek 1  Sat       Away           L
# 1     2000-09-09       NaN  La Liga   Matchweek 1  Sat       Home           W
# 2     2000-09-09       NaN  La Liga   Matchweek 1  Sat       Away           L
# 3     2000-09-09       NaN  La Liga   Matchweek 1  Sat       Away           L
# 4     2000-09-09       NaN  La Liga   Matchweek 1  Sat       Home           W
# ...          ...       ...      ...           ...  ...        ...         ...
# 16715 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun       Away           L
# 16716 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun       Home           W
# 16717 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun       Home           L
# 16718 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun       Away           W
# 16719 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun       Home           L
#
#       GF_team GA_team    Opponent_team  ...  HomeGoal  xG_Home  AwayGoal  \
# 0           1       2      Real Madrid  ...         2      NaN         1
# 1           2       0    Athletic Club  ...         2      NaN         0
# 2           1       2        Barcelona  ...         2      NaN         1
# 3           0       2        La Coruña  ...         2      NaN         0
# 4           2       1           Málaga  ...         2      NaN         1
# ...       ...     ...              ...  ...       ...      ...       ...
# 16715       0       1          Sevilla  ...         1      1.4         0
# 16716       1       0    Athletic Club  ...         1      1.4         0
# 16717       1       2  Atlético Madrid  ...         1      2.3         2
# 16718       2       0        Barcelona  ...         0      0.7         2
# 16719       0       2       Villarreal  ...         0      0.7         2
#
#        xG_Away HomeFormation AwayFormation HomePossession AwayPossession  \
# 0          NaN           NaN           NaN            NaN            NaN
# 1          NaN           NaN           NaN            NaN            NaN
# 2          NaN           NaN           NaN            NaN            NaN
# 3          NaN           NaN           NaN            NaN            NaN
# 4          NaN           NaN           NaN            NaN            NaN
# ...        ...           ...           ...            ...            ...
# 16715      0.7         4-3-3         4-4-2           65.0           35.0
# 16716      0.7         4-3-3         4-4-2           65.0           35.0
# 16717      0.8        4-4-2◆         3-5-2           61.0           39.0
# 16718      0.7         4-3-3         4-4-2           70.0           30.0
# 16719      0.7         4-3-3         4-4-2           70.0           30.0
#
#               HomeCaptain   AwayCaptain
# 0                     NaN           NaN
# 1                     NaN           NaN
# 2                     NaN           NaN
# 3                     NaN           NaN
# 4                     NaN           NaN
# ...                   ...           ...
# 16715         Jesús Navas  Iker Muniain
# 16716         Jesús Navas  Iker Muniain
# 16717  Asier Illarramendi          Koke
# 16718     Sergio Busquets  Mario Gaspar
# 16719     Sergio Busquets  Mario Gaspar
#
# [16720 rows x 41 columns]

# %%
# Drop unnecessary columns
scores_df_merge = scores_df_merge.loc[:, ["Date", "Time", "Comp", "Round", "Day", "Attendance", "Referee", "Home", "Away", "HomeGoal",
                        "xG_Home", "AwayGoal", "xG_Away", "HomeFormation", "AwayFormation", "HomePossession", "AwayPossession",
                        "HomeCaptain", "AwayCaptain"]]
scores_df_merge
# Out:
#             Date      Time     Comp         Round  Day  Attendance  \
# 0     2000-09-09       NaN  La Liga   Matchweek 1  Sat         NaN
# 1     2000-09-09       NaN  La Liga   Matchweek 1  Sat         NaN
# 2     2000-09-09       NaN  La Liga   Matchweek 1  Sat         NaN
# 3     2000-09-09       NaN  La Liga   Matchweek 1  Sat         NaN
# 4     2000-09-09       NaN  La Liga   Matchweek 1  Sat         NaN
# ...          ...       ...      ...           ...  ...         ...
# 16715 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun     31305.0
# 16716 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun     31305.0
# 16717 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun     23586.0
# 16718 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun     54850.0
# 16719 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun     54850.0
#
#                   Referee           Home             Away  HomeGoal  xG_Home  \
# 0           Daudén Ibáñez    Real Madrid         Valencia         2      NaN
# 1      Andradas Asurmendi      La Coruña    Athletic Club         2      NaN
# 2         Mejuto González      Barcelona           Málaga         2      NaN
# 3      Andradas Asurmendi      La Coruña    Athletic Club         2      NaN
# 4         Mejuto González      Barcelona           Málaga         2      NaN
# ...                   ...            ...              ...       ...      ...
# 16715    Carlos del Cerro        Sevilla    Athletic Club         1      1.4
# 16716    Carlos del Cerro        Sevilla    Athletic Club         1      1.4
# 16717           Jesús Gil  Real Sociedad  Atlético Madrid         1      2.3
# 16718   José Luis Munuera      Barcelona       Villarreal         0      0.7
# 16719   José Luis Munuera      Barcelona       Villarreal         0      0.7
#
#        AwayGoal  xG_Away HomeFormation AwayFormation  HomePossession  \
# 0             1      NaN           NaN           NaN             NaN
# 1             0      NaN           NaN           NaN             NaN
# 2             1      NaN           NaN           NaN             NaN
# 3             0      NaN           NaN           NaN             NaN
# 4             1      NaN           NaN           NaN             NaN
# ...         ...      ...           ...           ...             ...
# 16715         0      0.7         4-3-3         4-4-2            65.0
# 16716         0      0.7         4-3-3         4-4-2            65.0
# 16717         2      0.8        4-4-2◆         3-5-2            61.0
# 16718         2      0.7         4-3-3         4-4-2            70.0
# 16719         2      0.7         4-3-3         4-4-2            70.0
#
#        AwayPossession         HomeCaptain   AwayCaptain
# 0                 NaN                 NaN           NaN
# 1                 NaN                 NaN           NaN
# 2                 NaN                 NaN           NaN
# 3                 NaN                 NaN           NaN
# 4                 NaN                 NaN           NaN
# ...               ...                 ...           ...
# 16715            35.0         Jesús Navas  Iker Muniain
# 16716            35.0         Jesús Navas  Iker Muniain
# 16717            39.0  Asier Illarramendi          Koke
# 16718            30.0     Sergio Busquets  Mario Gaspar
# 16719            30.0     Sergio Busquets  Mario Gaspar
#
# [16720 rows x 19 columns]

# %%
scores_df_merge_final = scores_df_merge.drop_duplicates()
scores_df_merge_final
# Out:
#             Date      Time     Comp         Round  Day  Attendance  \
# 0     2000-09-09       NaT  La Liga   Matchweek 1  Sat         NaN
# 1     2000-09-09       NaT  La Liga   Matchweek 1  Sat         NaN
# 2     2000-09-09       NaT  La Liga   Matchweek 1  Sat         NaN
# 6     2000-09-09       NaT  La Liga   Matchweek 1  Sat         NaN
# 7     2000-09-09       NaT  La Liga   Matchweek 1  Sat         NaN
# ...          ...       ...      ...           ...  ...         ...
# 16709 2022-05-22  20:00:00  La Liga  Matchweek 38  Sun     11138.0
# 16711 2022-05-22  20:00:00  La Liga  Matchweek 38  Sun     17951.0
# 16714 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun     23586.0
# 16715 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun     31305.0
# 16718 2022-05-22  22:00:00  La Liga  Matchweek 38  Sun     54850.0
#
#                    Referee           Home             Away  HomeGoal  xG_Home  \
# 0            Daudén Ibáñez    Real Madrid         Valencia         2      NaN
# 1       Andradas Asurmendi      La Coruña    Athletic Club         2      NaN
# 2          Mejuto González      Barcelona           Málaga         2      NaN
# 6            Prados García  Real Sociedad      Racing Sant         2      NaN
# 7         Turienzo Álvarez       Zaragoza         Espanyol         1      NaN
# ...                    ...            ...              ...       ...      ...
# 16709         José Sánchez         Alavés            Cádiz         0      0.4
# 16711  Alejandro Hernández        Granada         Espanyol         0      2.0
# 16714            Jesús Gil  Real Sociedad  Atlético Madrid         1      2.3
# 16715     Carlos del Cerro        Sevilla    Athletic Club         1      1.4
# 16718    José Luis Munuera      Barcelona       Villarreal         0      0.7
#
#        AwayGoal  xG_Away HomeFormation AwayFormation  HomePossession  \
# 0             1      NaN           NaN           NaN             NaN
# 1             0      NaN           NaN           NaN             NaN
# 2             1      NaN           NaN           NaN             NaN
# 6             2      NaN           NaN           NaN             NaN
# 7             2      NaN           NaN           NaN             NaN
# ...         ...      ...           ...           ...             ...
# 16709         1      1.9       4-2-3-1         4-4-2            49.0
# 16711         0      0.4         4-3-3         4-4-2            40.0
# 16714         2      0.8        4-4-2◆         3-5-2            61.0
# 16715         0      0.7         4-3-3         4-4-2            65.0
# 16718         2      0.7         4-3-3         4-4-2            70.0
#
#        AwayPossession         HomeCaptain     AwayCaptain
# 0                 NaN                 NaN             NaN
# 1                 NaN                 NaN             NaN
# 2                 NaN                 NaN             NaN
# 6                 NaN                 NaN             NaN
# 7                 NaN                 NaN             NaN
# ...               ...                 ...             ...
# 16709            51.0        Rubén Duarte  Álex Fernández
# 16711            60.0         Víctor Díaz     David López
# 16714            39.0  Asier Illarramendi            Koke
# 16715            35.0         Jesús Navas    Iker Muniain
# 16718            30.0     Sergio Busquets    Mario Gaspar
#
# [8360 rows x 19 columns]

# %%
SCORES_OVERALL_DATA = os.path.join(FILE_PATH, "scores_overall.csv")
scores_overall_df = pd.read_csv(SCORES_OVERALL_DATA)
scores_overall_df = scores_overall_df.sort_values(["Date", "Time"])
scores_overall_df.drop(["Unnamed: 0", "Match Report", "Notes"], axis = 1, inplace = True)
scores_overall_df = scores_overall_df[scores_overall_df['Wk'].notnull()]

start_date = '2000-08-29'
end_date = '2022-05-30'
mask = (scores_overall_df['Date'] > start_date) & (scores_overall_df['Date'] <= end_date)
scores_overall_df = scores_overall_df.loc[mask]
scores_overall_df
# Out:
#         Wk  Day        Date   Time           Home   xG Score  xG.1  \
# 4613   1.0  Sat  2000-09-09    NaN       Zaragoza  NaN   1–2   NaN
# 4614   1.0  Sat  2000-09-09    NaN      Barcelona  NaN   2–1   NaN
# 4615   1.0  Sat  2000-09-09    NaN      La Coruña  NaN   2–0   NaN
# 4616   1.0  Sat  2000-09-09    NaN    Real Madrid  NaN   2–1   NaN
# 4617   1.0  Sat  2000-09-09    NaN  Real Sociedad  NaN   2–2   NaN
# ...    ...  ...         ...    ...            ...  ...   ...   ...
# 1255  38.0  Sun  2022-05-22  20:00         Alavés  0.4   0–1   1.9
# 1256  38.0  Sun  2022-05-22  20:00        Granada  2.0   0–0   0.4
# 1257  38.0  Sun  2022-05-22  22:00  Real Sociedad  2.3   1–2   0.8
# 1258  38.0  Sun  2022-05-22  22:00      Barcelona  0.7   0–2   0.7
# 1259  38.0  Sun  2022-05-22  22:00        Sevilla  1.4   1–0   0.7
#
#                  Away  Attendance                          Venue  \
# 4613         Espanyol         NaN                    La Romareda
# 4614           Málaga         NaN                       Nou Camp
# 4615    Athletic Club         NaN                   Nuevo Riazor
# 4616         Valencia         NaN              Santiago Bernabéu
# 4617      Racing Sant         NaN                         Anoeta
# ...               ...         ...                            ...
# 1255            Cádiz     11138.0        Estadio de Mendizorroza
# 1256         Espanyol     17951.0     Estadio Nuevo Los Cármenes
# 1257  Atlético Madrid     23586.0    Estadio Municipal de Anoeta
# 1258       Villarreal     54850.0                       Camp Nou
# 1259    Athletic Club     31305.0  Estadio Ramón Sánchez Pizjuán
#
#                   Referee
# 4613     Turienzo Álvarez
# 4614      Mejuto González
# 4615   Andradas Asurmendi
# 4616        Daudén Ibáñez
# 4617        Prados García
# ...                   ...
# 1255         José Sánchez
# 1256  Alejandro Hernández
# 1257            Jesús Gil
# 1258    José Luis Munuera
# 1259     Carlos del Cerro
#
# [8360 rows x 12 columns]

# %%
scores_overall_df['Date'] = pd.to_datetime(scores_overall_df['Date'], format = "%Y-%m-%d")
scores_overall_df['Time'] = pd.to_datetime(scores_overall_df['Time']).dt.time
scores_overall_df.columns
# pd.to_datetime(scores_overall_df['Date']).dt.date.dtype
# Out:
# Index(['Wk', 'Day', 'Date', 'Time', 'Home', 'xG', 'Score', 'xG.1', 'Away',
#        'Attendance', 'Venue', 'Referee'],
#       dtype='object')

# %%
scores_overall_df[['HomeGoal', 'AwayGoal']] = scores_overall_df.Score.str.split('–',expand = True)
scores_overall_df.rename(columns = {'xG': 'xG_Home', 'xG.1':'xG_Away'}, inplace = True)
scores_overall_df
# Out:
#         Wk  Day       Date      Time           Home  xG_Home Score  xG_Away  \
# 4613   1.0  Sat 2000-09-09       NaN       Zaragoza      NaN   1–2      NaN
# 4614   1.0  Sat 2000-09-09       NaN      Barcelona      NaN   2–1      NaN
# 4615   1.0  Sat 2000-09-09       NaN      La Coruña      NaN   2–0      NaN
# 4616   1.0  Sat 2000-09-09       NaN    Real Madrid      NaN   2–1      NaN
# 4617   1.0  Sat 2000-09-09       NaN  Real Sociedad      NaN   2–2      NaN
# ...    ...  ...        ...       ...            ...      ...   ...      ...
# 1255  38.0  Sun 2022-05-22  20:00:00         Alavés      0.4   0–1      1.9
# 1256  38.0  Sun 2022-05-22  20:00:00        Granada      2.0   0–0      0.4
# 1257  38.0  Sun 2022-05-22  22:00:00  Real Sociedad      2.3   1–2      0.8
# 1258  38.0  Sun 2022-05-22  22:00:00      Barcelona      0.7   0–2      0.7
# 1259  38.0  Sun 2022-05-22  22:00:00        Sevilla      1.4   1–0      0.7
#
#                  Away  Attendance                          Venue  \
# 4613         Espanyol         NaN                    La Romareda
# 4614           Málaga         NaN                       Nou Camp
# 4615    Athletic Club         NaN                   Nuevo Riazor
# 4616         Valencia         NaN              Santiago Bernabéu
# 4617      Racing Sant         NaN                         Anoeta
# ...               ...         ...                            ...
# 1255            Cádiz     11138.0        Estadio de Mendizorroza
# 1256         Espanyol     17951.0     Estadio Nuevo Los Cármenes
# 1257  Atlético Madrid     23586.0    Estadio Municipal de Anoeta
# 1258       Villarreal     54850.0                       Camp Nou
# 1259    Athletic Club     31305.0  Estadio Ramón Sánchez Pizjuán
#
#                   Referee HomeGoal AwayGoal
# 4613     Turienzo Álvarez        1        2
# 4614      Mejuto González        2        1
# 4615   Andradas Asurmendi        2        0
# 4616        Daudén Ibáñez        2        1
# 4617        Prados García        2        2
# ...                   ...      ...      ...
# 1255         José Sánchez        0        1
# 1256  Alejandro Hernández        0        0
# 1257            Jesús Gil        1        2
# 1258    José Luis Munuera        0        2
# 1259     Carlos del Cerro        1        0
#
# [8360 rows x 14 columns]

# %% [markdown]
# # Merge Tables
# Merge the Scores Overall Data to the Scores by Team Data

# %%
print(scores_overall_df.columns)
print()
print(scores_df_merge_final.columns)
# Out:
# Index(['Wk', 'Day', 'Date', 'Time', 'Home', 'xG_Home', 'Score', 'xG_Away',
#        'Away', 'Attendance', 'Venue', 'Referee', 'HomeGoal', 'AwayGoal'],
#       dtype='object')
#
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Attendance', 'Referee', 'Home',
#        'Away', 'HomeGoal', 'xG_Home', 'AwayGoal', 'xG_Away', 'HomeFormation',
#        'AwayFormation', 'HomePossession', 'AwayPossession', 'HomeCaptain',
#        'AwayCaptain'],
#       dtype='object')

# %%
# scores_merge = scores_overall_df.merge(scores_df_merge_final, on = ["Date", "Time", "Day", "Referee", "Attendance", "Home", "Away",
#                                                        "HomeGoal", "AwayGoal", "xG_Home", "xG_Away"], how = "inner")
# scores_merge
